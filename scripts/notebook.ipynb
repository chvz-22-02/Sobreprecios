# %% [markdown]
# # Entidades

# %%
uv pip install openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Using Python 3.13.7 environment at: c:\Users\mschavez\Documents\GitHub\Sobreprecios\.venv
# Audited 1 package in 17ms

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
entidades = pd.read_pickle('../data/interim/entidades.pickle')
adjudicaciones = pd.read_pickle('../data/interim/adjudicaciones.pickle')

# %%
df_adjudicaciones = adjudicaciones[['codigoentidad', 'tipoentidad']].set_index('codigoentidad')
df_entidades = entidades[['RUC', 'NOMBRE_DE_ENTIDAD', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'CODCONSUCODE']].set_index('CODCONSUCODE')

# %%
df_entidades.join(df_adjudicaciones, how='right').to_csv('../data/processed/D_entidades.csv', sep='|', index=True)

# %% [markdown]
# # F_adjudicaciones

# %%
adjudicaciones = pd.read_pickle('../data/interim/adjudicaciones.pickle')
convocatorias = pd.read_pickle('../data/interim/convocatorias.pickle')

# %%
df_adjudicaciones = adjudicaciones[['codigoconvocatoria', 'n_item', 'codigoentidad', 'ruc_proveedor', 'objetocontractual', 'tipoprocesoseleccion', 
                                    'proceso', 'descripcion_proceso', 'unidad_medida', 'cantidad_adjudicado_item', 'estado_item', 
                                    'descripcion_item', 'fecha_convocatoria', 'fecha_buenapro', 'fecha_consentimiento_bp', 
                                    'monto_referencial_item_soles', 'monto_adjudicado_item_soles']]
df_adjudicaciones['cn'] = df_adjudicaciones['codigoconvocatoria'].astype(str) + '-' + df_adjudicaciones['n_item'].astype(str)
df_adjudicaciones = df_adjudicaciones.set_index('cn')
df_convocatorias = convocatorias[['codigoconvocatoria', 'n_item', 'departamento_item', 'provincia_item', 'distrito_item', 
                                  'itemcubso']].drop_duplicates()
df_convocatorias['cn'] = df_convocatorias['codigoconvocatoria'].astype(str) + '-' + df_convocatorias['n_item'].astype(str)
df_convocatorias = df_convocatorias.drop(columns=['codigoconvocatoria', 'n_item']).set_index('cn')

# %%
df_adjudicaciones.join(df_convocatorias, how='left').to_csv('../data/processed/F_adjudicaciones.csv', sep='|', index=True)

# %% [markdown]
# F_Postores

# %%
convocatorias = pd.read_pickle('../data/interim/convocatorias.pickle')
adjudicaciones = pd.read_pickle('../data/interim/adjudicaciones.pickle')

# %%
convocatorias[['codigoconvocatoria', 'n_item', 'entidad_ruc']]

# %%
convocatorias
# Out:
#       codigoentidad  entidad_ruc  \
# 0            200276  20521286769
# 1            000035  20452393493
# 2            010479  20401788990
# 3            001068  20133696823
# 4            001925  20147797011
# ...             ...          ...
# 58510        000182  20203904500
# 58511        000049  20406325815
# 58512        000819  20170327391
# 58513        010182  20330611023
# 58514        010356  20156058719
#
#                                                  entidad        tipoentidad  \
# 58514            DIRECTA-DIRECTA-1-2025--PECH-1  Por la Entidad
#
#       objetocontractual SECTOR / NIVEL DE GOBIERNO sistema_contratacion  \
# 0              Servicio                   AMBIENTE          Suma alzada
# 1                  Bien          GOBIERNO REGIONAL          Suma alzada
# 2              Servicio          GOBIERNO REGIONAL          Suma alzada
# 3                  Bien             GOBIERNO LOCAL          Suma alzada
# 4              Servicio          GOBIERNO REGIONAL    Precios unitarios
# ...                 ...                        ...                  ...
# 58510              Obra             GOBIERNO LOCAL          Suma alzada
# 58511              Bien          GOBIERNO REGIONAL          Suma alzada
# 58512              Bien             GOBIERNO LOCAL          Suma alzada
# 58513          Servicio                  EDUCACIÓN    Precios unitarios
# 58514              Obra          GOBIERNO REGIONAL    Precios unitarios
#
#                tipoprocesoseleccion montoreferencial n_item  \
# 0                  Regímen Especial         18000.00      1
# 1            Comparación de Precios         97920.00      1
# 2         Adjudicación Simplificada        241427.42      1
# 3      Licitación Pública Abreviada        352000.00      1
# 4         Adjudicación Simplificada         77029.07      1
# ...                             ...              ...    ...
# 58510  Licitación Pública Abreviada        695759.67      1
# 58511  Licitación Pública Abreviada         52900.00      1
# 58512   Subasta Inversa Electrónica         56400.00      1
# 58513    Concurso Público Abreviado        275096.00      1
# 58514          Contratación Directa       7470477.06      1
#
#                                         descripcion_item unidad_medida  \
# 0                      SERVICIO DE SUPERVISI¿N AMBIENTAL      Servicio
# 1      ADQUISICION DE MADERA TORNILLO (203.20MM X 304...        Unidad
# 2      SERVICIO DE EJECUCI¿N DE MANTENIMIENTO RUTINAR...      Servicio
# 3      ADQUISICION DE CAMARA DE VIDEO DIGITAL IP TIPO...        Unidad
# 4           SERVICIO DE TRANSPORTE Y TRASLADO DE VALORES      Servicio
# ...                                                  ...           ...
# 58510  EJECUCION DE LA OBRA: "MEJORAMIENTO DEL SERVIC...      Servicio
# 58511                                          COMEDEROS        Unidad
# 58512       FERTILIZANTE COMPUESTO NPK + MICRONUTRIENTES        Unidad
# 58513  SERVICIO DE MANTENIMIENTO PREVENTIVO Y CORRECT...      Servicio
# 58514  CONTRATACI¿N DE LA EJECUCI¿N DEL SALDO DE OBRA...        Unidad
#
#        estadoitem paquete codigoitem  \
# 0      Contratado      NO   00228925
# 1      Contratado      NO   00315851
# 2      Contratado      NO   00333938
# 3      Contratado      NO   00079334
# 4      Contratado      NO   00232491
# ...           ...     ...        ...
# 58510  Contratado      NO   00342329
# 58511  Contratado      NO   00280789
# 58512  Contratado      NO   00131789
# 58513  Contratado      NO   00385661
# 58514  Contratado      NO   00364491
#
#                                                itemcubso  \
# 0      SERVICIO DE SEGUIMIENTO Y MONITOREO DE ACTIVID...
# 1            MADERA TORNILLO DE 1 1/2 in X 10 in X 13 ft
# 2      SERVICIO DE MANTENIMIENTO RUTINARIO DE CARRETERAS
# 3        CAMARA DE VIDEO DIGITAL DE 4 APROX. MEGAPIXELES
# 4                      SERVICIO DE TRANSPORTE DE VALORES
# ...                                                  ...
# 58510                   MEJORAMIENTO DE PISTAS Y VEREDAS
# 58511                      COMEDERO DE MADERA PARA VACAS
# 58512  FERTILIZANTE FOLIAR NITROGENO FOSFORO POTASIO ...
# 58513  SERVICIO DE MANTENIMIENTO CORRECTIVO DE COMPUT...
# 58514                     AMPLIACION DE CANALES DE RIEGO
#
#       monto_referencial_item moneda departamento_item provincia_item  \
# 0                      18000  Soles              LIMA           LIMA
# 1                      97920  Soles          AYACUCHO       HUAMANGA
# 2                  241427.42  Soles             JUNIN       HUANCAYO
# 3                     352000  Soles             JUNIN       HUANCAYO
# 4                   77029.07  Soles             TACNA          TACNA
# ...                      ...    ...               ...            ...
# 58510              695759.67  Soles            ANCASH      BOLOGNESI
# 58511                  52900  Soles              PUNO          LAMPA
# 58512                  56400  Soles             CUSCO  LA CONVENCION
# 58513                 275096  Soles              LIMA           LIMA
# 58514             7470477.06  Soles       LA LIBERTAD           VIRU
#
#                          distrito_item   fecha_convocatoria  \
# 0                          JESUS MARIA  2025-02-14 00:00:00
# 1      ANDRÉS AVELINO CÁCERES DORREGAY  2025-07-10 00:00:00
# 2                             HUANCAYO  2025-03-21 00:00:00
# 3                             HUANCAYO  2025-10-27 00:00:00
# 4                                TACNA  2025-03-05 00:00:00
# ...                                ...                  ...
# 58510                     HUAYLLACAYAN  2025-09-30 00:00:00
# 58511                        CABANILLA  2025-08-28 00:00:00
# 58512                       VILCABAMBA  2025-03-20 00:00:00
# 58513                             LIMA  2025-10-21 00:00:00
# 58514                             CHAO  2025-10-21 00:00:00
#
#       fechaintegracionbases fechapresentacionpropuesta  \
# 0                       NaN        2025-02-14 00:00:00
# 1                       NaN        2025-07-15 00:00:00
# 2       2025-03-31 00:00:00        2025-04-03 00:00:00
# 3       2025-11-07 00:00:00        2025-11-13 00:00:00
# 4       2025-03-10 00:00:00        2025-03-14 00:00:00
# ...                     ...                        ...
# 58510   2025-10-06 00:00:00        2025-10-10 00:00:00
# 58511   2025-09-11 00:00:00        2025-09-16 00:00:00
# 58512                   NaN        2025-03-21 00:00:00
# 58513   2025-10-28 00:00:00        2025-11-04 00:00:00
# 58514                   NaN                        NaN
#
#                                               ORIGEN
# 0      ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 1      ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 2      ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 3      ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 4      ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# ...                                              ...
# 58510  ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 58511  ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 58512  ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 58513  ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
# 58514  ../data/raw//CONOSCE_CONVOCATORIAS2025_0.xlsx
#
# [58515 rows x 29 columns]
